# %% [markdown]
# ## Data Preprocessing

# %%
import os
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# Download NLTK resources if not already downloaded
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Define the path to your directory
directory = '/content/drive/MyDrive/MscIT/3rd Trimester/6th Session/AIM 600 Information Retreival - Siman Giri/Week 4 Assignment/IR Assignment/Syllabus Description Dataset'

# %%
stop_words = set(stopwords.words('english'))

# %%
# Function to remove punctuation, whitespaces, and stopwords
def preprocess_text(text):
    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)
    # Remove extra whitespaces
    text = re.sub(r'\s+', ' ', text)
    # Remove leading and trailing whitespaces
    text = text.strip()
    # Remove numbers
    text = re.sub(r'\b\d+\b', '', text)
    # Convert to lowercase and tokenize
    tokens = word_tokenize(text.lower())
    # Remove stopwords and single-letter words
    tokens = [token for token in tokens if token not in stop_words and not token.isdigit()]
    return tokens

# %%
# Loop through each file in the directory
for filename in os.listdir(directory):
    if filename.endswith(".txt"):
        file_path = os.path.join(directory, filename)
        with open(file_path, 'r') as file:
            text = file.read()
            # Preprocess the text
            preprocessed_tokens = preprocess_text(text)
            # Print 50 tokens for each document
            preprocessed_words = preprocessed_tokens[:50]
            print(f"Tokens for {filename}: {preprocessed_words}")
# Out:
# Tokens for 1.txt: ['course', 'name', 'semantic', 'web', 'technology', 'course', 'provides', 'comprehensive', 'exploration', 'fundamental', 'principles', 'concepts', 'applications', 'semantic', 'web', 'technology', 'encompassing', 'elevated', 'concepts', 'within', 'field', 'including', 'foundational', 'principles', 'semantic', 'web', 'technology', 'intricacies', 'rdf', 'resource', 'description', 'framework', 'rdf', 'schema', 'rdf', 'plus', 'sparql', 'query', 'techniques', 'linked', 'data', 'nuances', 'owl', 'web', 'ontology', 'language', 'conceptualization', 'application', 'ontologies', 'students']
# Tokens for 2.txt: ['course', 'name', 'information', 'retrieval', 'course', 'provides', 'concepts', 'procedures', 'methods', 'required', 'theory', 'implementation', 'evaluation', 'information', 'retrieval', 'ir', 'systems', 'aims', 'develop', 'broad', 'understanding', 'means', 'information', 'access', 'using', 'information', 'retrieval', 'topics', 'covered', 'include', 'basics', 'information', 'retrieval', 'focusing', 'heart', 'search', 'engine', 'advanced', 'knowledge', 'various', 'types', 'information', 'course', 'learning', 'outcomes', 'implement', 'document', 'preprocessing', 'identification', 'indexes']
# Tokens for 9.txt: ['course', 'name', 'managing', 'information', 'systems', 'technology', 'course', 'focuses', 'impact', 'technology', 'organizations', 'topics', 'include', 'information', 'awareness', 'decision', 'architecture', 'internal', 'knowledge', 'dissemination', 'addition', 'course', 'covers', 'tools', 'techniques', 'competitive', 'analysis', 'strategic', 'planning', 'strategy', 'implementation', 'addressing', 'use', 'information', 'knowledge', 'technology', 'strategic', 'asset', 'course', 'learning', 'outcomes', 'demonstrate', 'importance', 'information', 'systems', 'role', 'improving', 'efficiency', 'effectiveness', 'business']
# Tokens for 11.txt: ['course', 'name', 'research', 'methodology', 'course', 'provides', 'knowledge', 'skills', 'required', 'conduct', 'write', 'scientific', 'research', 'focus', 'computer', 'science', 'course', 'helps', 'students', 'understand', 'conduct', 'different', 'research', 'activities', 'course', 'covers', 'following', 'topics', 'fundamental', 'concepts', 'research', 'literature', 'reviews', 'technical', 'reading', 'attributions', 'citation', 'styles', 'research', 'article', 'writing', 'publishing', 'communication', 'audiences', 'ethics', 'intellectual', 'property', 'rights', 'course', 'learning']
# Tokens for 12.txt: ['course', 'name', 'virtualization', 'storage', 'course', 'provides', 'students', 'overview', 'cloud', 'computing', 'concepts', 'functional', 'technologies', 'handson', 'experience', 'projects', 'utilizing', 'public', 'cloud', 'infrastructures', 'amazon', 'web', 'services', 'aws', 'microsoft', 'azure', 'cloud', 'computing', 'services', 'adopted', 'widely', 'across', 'variety', 'organizations', 'many', 'domains', 'course', 'introduces', 'cloud', 'computing', 'domain', 'covers', 'topics', 'focusing', 'storage', 'virtualization', 'cloud', 'infrastructures', 'course', 'learning']
# Tokens for 10.txt: ['course', 'name', 'information', 'technology', 'project', 'management', 'course', 'provides', 'students', 'concepts', 'tools', 'techniques', 'managing', 'projects', 'sphere', 'based', 'project', 'management', 'institutes', 'pmi', 'guide', 'project', 'management', 'body', 'knowledge', 'pmbok', 'course', 'helps', 'students', 'apply', 'appropriate', 'theories', 'principles', 'practices', 'skills', 'techniques', 'facilitate', 'planning', 'organization', 'management', 'control', 'projects', 'face', 'organizations', 'course', 'learning', 'outcomes', 'apply', 'principles', 'project']
# Tokens for 8.txt: ['course', 'name', 'internet', 'things', 'iot', 'course', 'focuses', 'internet', 'things', 'iot', 'concepts', 'sensing', 'actuation', 'communication', 'program', 'teaches', 'practical', 'skills', 'strengthened', 'core', 'theories', 'students', 'able', 'gain', 'knowledge', 'areas', 'iot', 'addition', 'describing', 'functional', 'foundational', 'aspects', 'major', 'iot', 'system', 'components', 'emphasis', 'integration', 'ie', 'components', 'building', 'blocks', 'combined', 'create', 'complete', 'iot', 'systems', 'course', 'covers', 'following']
# Tokens for 7.txt: ['course', 'name', 'metaverse', 'introductory', 'course', 'metaverse', 'metaverse', 'innovative', 'concept', 'many', 'people', 'reasonably', 'confused', 'metaverse', 'basics', 'become', 'popular', 'recently', 'students', 'learn', 'metaverse', 'explore', 'opportunities', 'holds', 'store', 'digital', 'transformation', 'dive', 'deeper', 'core', 'concepts', 'underlying', 'development', 'environment', 'explore', 'different', 'use', 'cases', 'applications', 'metaverse', 'learning', 'best', 'practices', 'implementing', 'course', 'learning', 'outcomes', 'define', 'examine', 'concept']
# Tokens for 6.txt: ['course', 'name', 'data', 'science', 'course', 'provides', 'concepts', 'procedures', 'methods', 'required', 'applying', 'data', 'science', 'realworld', 'applications', 'purpose', 'course', 'help', 'students', 'develop', 'broad', 'understanding', 'discipline', 'data', 'science', 'following', 'practical', 'application', 'approach', 'topics', 'covered', 'course', 'address', 'basic', 'concepts', 'behind', 'many', 'data', 'science', 'techniques', 'providing', 'programmatic', 'mathematical', 'knowledge', 'course', 'learning', 'outcomes', 'discuss', 'life', 'cycle']
# Tokens for 5.txt: ['course', 'name', 'applied', 'algebra', 'machine', 'learning', 'course', 'provides', 'students', 'knowledge', 'concepts', 'found', 'linear', 'algebra', 'application', 'machine', 'learning', 'concepts', 'include', 'system', 'equations', 'matrices', 'vector', 'space', 'norm', 'inner', 'product', 'matrix', 'decompositions', 'matrix', 'approximation', 'matrix', 'phylogeny', 'course', 'learning', 'outcomes', 'identify', 'fundamental', 'concepts', 'system', 'linear', 'equations', 'matrices', 'solutions', 'recognize', 'properties', 'vector', 'space', 'vector', 'subspace']
# Tokens for 4.txt: ['course', 'name', 'artificial', 'intelligence', 'machine', 'learning', 'course', 'designed', 'students', 'interested', 'learning', 'artificial', 'intelligence', 'ai', 'machine', 'learning', 'goal', 'course', 'ensure', 'students', 'education', 'training', 'necessary', 'succeed', 'aipowered', 'future', 'course', 'guides', 'students', 'latest', 'advancements', 'technical', 'approaches', 'ai', 'technologies', 'natural', 'language', 'processing', 'predictive', 'analytics', 'deep', 'learning', 'algorithmic', 'methods', 'knowledge', 'everevolving', 'industry', 'course', 'learning', 'outcomes']
# Tokens for 3.txt: ['course', 'name', 'artificial', 'neural', 'network', 'deep', 'learning', 'course', 'focuses', 'foundations', 'artificial', 'neural', 'deep', 'learning', 'help', 'students', 'understand', 'neural', 'networks', 'human', 'brain', 'students', 'learn', 'artificial', 'intelligence', 'technologies', 'methods', 'applications', 'computer', 'vision', 'natural', 'language', 'processing', 'students', 'also', 'gain', 'foundational', 'knowledge', 'practical', 'experience', 'building', 'neural', 'networks', 'using', 'tools', 'tensorflow', 'keras', 'course', 'learning', 'outcomes']

# %% [markdown]
# ## Term-Document Incidence Matrix

# %%
from collections import defaultdict

# %%
# Initialize the term-document incidence matrix
term_doc_matrix = defaultdict(lambda: defaultdict(int))

# %%
# Loop through each file in the directory
for filename in os.listdir(directory):
    if filename.endswith(".txt"):
        file_path = os.path.join(directory, filename)
        with open(file_path, 'r') as file:
            text = file.read()
            # Preprocess the text
            preprocessed_tokens = preprocess_text(text)
            # Update term-document matrix
            for token in set(preprocessed_tokens):  # Ensure each term is counted once per document
                term_doc_matrix[token][filename] += 1

# %%
# Print the term-document incidence matrix
print("Term-Document Incidence Matrix:")
for term, doc_counts in term_doc_matrix.items():
    print(term, doc_counts)
# Out:
# Term-Document Incidence Matrix:
# principles defaultdict(<class 'int'>, {'1.txt': 1, '10.txt': 1, '3.txt': 1})
# conceptualization defaultdict(<class 'int'>, {'1.txt': 1})
# linked defaultdict(<class 'int'>, {'1.txt': 1})
# demonstrations defaultdict(<class 'int'>, {'1.txt': 1})
# within defaultdict(<class 'int'>, {'1.txt': 1})
# schemas defaultdict(<class 'int'>, {'1.txt': 1})
# processes defaultdict(<class 'int'>, {'1.txt': 1, '9.txt': 1, '10.txt': 1, '4.txt': 1})
# conversant defaultdict(<class 'int'>, {'1.txt': 1})
# name defaultdict(<class 'int'>, {'1.txt': 1, '2.txt': 1, '9.txt': 1, '11.txt': 1, '12.txt': 1, '10.txt': 1, '8.txt': 1, '7.txt': 1, '6.txt': 1, '5.txt': 1, '4.txt': 1, '3.txt': 1})
# support defaultdict(<class 'int'>, {'1.txt': 1})
# course defaultdict(<class 'int'>, {'1.txt': 1, '2.txt': 1, '9.txt': 1, '11.txt': 1, '12.txt': 1, '10.txt': 1, '8.txt': 1, '7.txt': 1, '6.txt': 1, '5.txt': 1, '4.txt': 1, '3.txt': 1})
# exploration defaultdict(<class 'int'>, {'1.txt': 1})
# including defaultdict(<class 'int'>, {'1.txt': 1, '9.txt': 1})
# artifacts defaultdict(<class 'int'>, {'1.txt': 1})
# databases defaultdict(<class 'int'>, {'1.txt': 1})
# queries defaultdict(<class 'int'>, {'1.txt': 1})
# outcomes defaultdict(<class 'int'>, {'1.txt': 1, '2.txt': 1, '9.txt': 1, '11.txt': 1, '12.txt': 1, '10.txt': 1, '8.txt': 1, '7.txt': 1, '6.txt': 1, '5.txt': 1, '4.txt': 1, '3.txt': 1})
# encompassing defaultdict(<class 'int'>, {'1.txt': 1})
# functioning defaultdict(<class 'int'>, {'1.txt': 1})
# thus defaultdict(<class 'int'>, {'1.txt': 1})
# analogous defaultdict(<class 'int'>, {'1.txt': 1})
# framework defaultdict(<class 'int'>, {'1.txt': 1, '2.txt': 1, '4.txt': 1})
# manner defaultdict(<class 'int'>, {'1.txt': 1, '2.txt': 1, '11.txt': 1, '8.txt': 1, '6.txt': 1, '5.txt': 1, '3.txt': 1})
# learning defaultdict(<class 'int'>, {'1.txt': 1, '2.txt': 1, '9.txt': 1, '11.txt': 1, '12.txt': 1, '10.txt': 1, '8.txt': 1, '7.txt': 1, '6.txt': 1, '5.txt': 1, '4.txt': 1, '3.txt': 1})
# internet defaultdict(<class 'int'>, {'1.txt': 1, '8.txt': 1, '7.txt': 1})
# disparate defaultdict(<class 'int'>, {'1.txt': 1})
# foundational defaultdict(<class 'int'>, {'1.txt': 1, '8.txt': 1, '3.txt': 1})
# fundamental defaultdict(<class 'int'>, {'1.txt': 1, '11.txt': 1, '5.txt': 1})
# sparql defaultdict(<class 'int'>, {'1.txt': 1})
# owl defaultdict(<class 'int'>, {'1.txt': 1})
# construct defaultdict(<class 'int'>, {'1.txt': 1, '10.txt': 1})
# machines defaultdict(<class 'int'>, {'1.txt': 1})
# interpret defaultdict(<class 'int'>, {'1.txt': 1})
# impact defaultdict(<class 'int'>, {'1.txt': 1, '9.txt': 1, '8.txt': 1})
# become defaultdict(<class 'int'>, {'1.txt': 1, '7.txt': 1})
# ways defaultdict(<class 'int'>, {'1.txt': 1})
# schema defaultdict(<class 'int'>, {'1.txt': 1})
# applications defaultdict(<class 'int'>, {'1.txt': 1, '12.txt': 1, '7.txt': 1, '6.txt': 1, '3.txt': 1})
# effectively defaultdict(<class 'int'>, {'1.txt': 1, '6.txt': 1})
# ontology defaultdict(<class 'int'>, {'1.txt': 1})
# structured defaultdict(<class 'int'>, {'1.txt': 1})
# enabled defaultdict(<class 'int'>, {'1.txt': 1})
# design defaultdict(<class 'int'>, {'1.txt': 1})
# human defaultdict(<class 'int'>, {'1.txt': 1, '3.txt': 1})
# standard defaultdict(<class 'int'>, {'1.txt': 1})
# understanding defaultdict(<class 'int'>, {'1.txt': 1, '2.txt': 1, '6.txt': 1})
# application defaultdict(<class 'int'>, {'1.txt': 1, '6.txt': 1, '5.txt': 1, '4.txt': 1})
# realworld defaultdict(<class 'int'>, {'1.txt': 1, '2.txt': 1, '6.txt': 1, '5.txt': 1, '3.txt': 1})
# better defaultdict(<class 'int'>, {'1.txt': 1})
# sources defaultdict(<class 'int'>, {'1.txt': 1, '11.txt': 1})
# interoperability defaultdict(<class 'int'>, {'1.txt': 1})
# retrieving defaultdict(<class 'int'>, {'1.txt': 1})
# create defaultdict(<class 'int'>, {'1.txt': 1, '10.txt': 1, '8.txt': 1})
# concepts defaultdict(<class 'int'>, {'1.txt': 1, '2.txt': 1, '11.txt': 1, '12.txt': 1, '10.txt': 1, '8.txt': 1, '7.txt': 1, '6.txt': 1, '5.txt': 1, '4.txt': 1})
# plus defaultdict(<class 'int'>, {'1.txt': 1})
# projects defaultdict(<class 'int'>, {'1.txt': 1, '12.txt': 1, '10.txt': 1})
# formulate defaultdict(<class 'int'>, {'1.txt': 1})
# combining defaultdict(<class 'int'>, {'1.txt': 1})
# translating defaultdict(<class 'int'>, {'1.txt': 1})
# techniques defaultdict(<class 'int'>, {'1.txt': 1, '9.txt': 1, '10.txt': 1, '8.txt': 1, '6.txt': 1})
# data defaultdict(<class 'int'>, {'1.txt': 1, '2.txt': 1, '9.txt': 1, '12.txt': 1, '6.txt': 1, '4.txt': 1, '3.txt': 1})
# problems defaultdict(<class 'int'>, {'1.txt': 1, '2.txt': 1, '10.txt': 1, '6.txt': 1, '5.txt': 1, '3.txt': 1})
# elevated defaultdict(<class 'int'>, {'1.txt': 1})
# utility defaultdict(<class 'int'>, {'1.txt': 1})
# intricacies defaultdict(<class 'int'>, {'1.txt': 1})
# resource defaultdict(<class 'int'>, {'1.txt': 1, '9.txt': 1})
# rdf defaultdict(<class 'int'>, {'1.txt': 1})
# analyze defaultdict(<class 'int'>, {'1.txt': 1, '7.txt': 1})
# provides defaultdict(<class 'int'>, {'1.txt': 1, '2.txt': 1, '11.txt': 1, '12.txt': 1, '10.txt': 1, '6.txt': 1, '5.txt': 1})
# field defaultdict(<class 'int'>, {'1.txt': 1})
# storing defaultdict(<class 'int'>, {'1.txt': 1})
# semantic defaultdict(<class 'int'>, {'1.txt': 1})
# query defaultdict(<class 'int'>, {'1.txt': 1, '2.txt': 1})
# finding defaultdict(<class 'int'>, {'1.txt': 1})
# nuances defaultdict(<class 'int'>, {'1.txt': 1})
# web defaultdict(<class 'int'>, {'1.txt': 1, '2.txt': 1, '12.txt': 1})
# ontologies defaultdict(<class 'int'>, {'1.txt': 1})
# systems defaultdict(<class 'int'>, {'1.txt': 1, '2.txt': 1, '9.txt': 1, '8.txt': 1})
# using defaultdict(<class 'int'>, {'1.txt': 1, '2.txt': 1, '10.txt': 1, '6.txt': 1, '3.txt': 1})
# comprehensive defaultdict(<class 'int'>, {'1.txt': 1})
# allowing defaultdict(<class 'int'>, {'1.txt': 1})
# technology defaultdict(<class 'int'>, {'1.txt': 1, '9.txt': 1, '10.txt': 1, '8.txt': 1, '7.txt': 1, '4.txt': 1})
# students defaultdict(<class 'int'>, {'1.txt': 1, '11.txt': 1, '12.txt': 1, '10.txt': 1, '8.txt': 1, '7.txt': 1, '6.txt': 1, '5.txt': 1, '4.txt': 1, '3.txt': 1})
# address defaultdict(<class 'int'>, {'1.txt': 1, '6.txt': 1})
# language defaultdict(<class 'int'>, {'1.txt': 1, '4.txt': 1, '3.txt': 1})
# description defaultdict(<class 'int'>, {'1.txt': 1})
# relevant defaultdict(<class 'int'>, {'1.txt': 1, '6.txt': 1})
# information defaultdict(<class 'int'>, {'1.txt': 1, '2.txt': 1, '9.txt': 1, '10.txt': 1, '8.txt': 1})
# include defaultdict(<class 'int'>, {'2.txt': 1, '9.txt': 1, '5.txt': 1})
# advanced defaultdict(<class 'int'>, {'2.txt': 1, '4.txt': 1})
# models defaultdict(<class 'int'>, {'2.txt': 1, '8.txt': 1})
# relevance defaultdict(<class 'int'>, {'2.txt': 1})
# algebra defaultdict(<class 'int'>, {'2.txt': 1, '5.txt': 1})
# engines defaultdict(<class 'int'>, {'2.txt': 1})
# indexes defaultdict(<class 'int'>, {'2.txt': 1})
# acts defaultdict(<class 'int'>, {'2.txt': 1})
# processing defaultdict(<class 'int'>, {'2.txt': 1, '4.txt': 1, '3.txt': 1})
# theory defaultdict(<class 'int'>, {'2.txt': 1})
# various defaultdict(<class 'int'>, {'2.txt': 1, '7.txt': 1, '4.txt': 1, '3.txt': 1})
# procedures defaultdict(<class 'int'>, {'2.txt': 1, '6.txt': 1})
# topics defaultdict(<class 'int'>, {'2.txt': 1, '9.txt': 1, '11.txt': 1, '12.txt': 1, '8.txt': 1, '6.txt': 1})
# crawler defaultdict(<class 'int'>, {'2.txt': 1})
# science defaultdict(<class 'int'>, {'2.txt': 1, '11.txt': 1, '6.txt': 1})
# identification defaultdict(<class 'int'>, {'2.txt': 1})
# access defaultdict(<class 'int'>, {'2.txt': 1})
# aims defaultdict(<class 'int'>, {'2.txt': 1})
# case defaultdict(<class 'int'>, {'2.txt': 1, '12.txt': 1, '8.txt': 1, '6.txt': 1, '5.txt': 1, '3.txt': 1})
# solve defaultdict(<class 'int'>, {'2.txt': 1, '10.txt': 1, '6.txt': 1, '5.txt': 1, '3.txt': 1})
# broad defaultdict(<class 'int'>, {'2.txt': 1, '6.txt': 1})
# search defaultdict(<class 'int'>, {'2.txt': 1})
# implement defaultdict(<class 'int'>, {'2.txt': 1, '8.txt': 1, '3.txt': 1})
# document defaultdict(<class 'int'>, {'2.txt': 1})
# preprocessing defaultdict(<class 'int'>, {'2.txt': 1})
# implementation defaultdict(<class 'int'>, {'2.txt': 1, '9.txt': 1, '10.txt': 1})
# probability defaultdict(<class 'int'>, {'2.txt': 1})
# engine defaultdict(<class 'int'>, {'2.txt': 1})
# retrieval defaultdict(<class 'int'>, {'2.txt': 1})
# heart defaultdict(<class 'int'>, {'2.txt': 1})
# demonstrate defaultdict(<class 'int'>, {'2.txt': 1, '9.txt': 1, '11.txt': 1, '8.txt': 1, '6.txt': 1, '5.txt': 1, '4.txt': 1, '3.txt': 1})
# increasing defaultdict(<class 'int'>, {'2.txt': 1})
# types defaultdict(<class 'int'>, {'2.txt': 1, '9.txt': 1, '11.txt': 1, '3.txt': 1})
# solutions defaultdict(<class 'int'>, {'2.txt': 1, '9.txt': 1, '12.txt': 1, '10.txt': 1, '8.txt': 1, '6.txt': 1, '5.txt': 1, '3.txt': 1})
# methods defaultdict(<class 'int'>, {'2.txt': 1, '11.txt': 1, '6.txt': 1, '4.txt': 1, '3.txt': 1})
# covered defaultdict(<class 'int'>, {'2.txt': 1, '6.txt': 1})
# evaluate defaultdict(<class 'int'>, {'2.txt': 1, '9.txt': 1, '12.txt': 1, '3.txt': 1})
# ranking defaultdict(<class 'int'>, {'2.txt': 1})
# probabilistic defaultdict(<class 'int'>, {'2.txt': 1})
# structure defaultdict(<class 'int'>, {'2.txt': 1, '11.txt': 1})
# apply defaultdict(<class 'int'>, {'2.txt': 1, '12.txt': 1, '10.txt': 1, '8.txt': 1, '7.txt': 1, '6.txt': 1, '5.txt': 1, '3.txt': 1})
# professional defaultdict(<class 'int'>, {'2.txt': 1, '11.txt': 1, '8.txt': 1, '6.txt': 1, '5.txt': 1, '3.txt': 1})
# ir defaultdict(<class 'int'>, {'2.txt': 1})
# basics defaultdict(<class 'int'>, {'2.txt': 1, '7.txt': 1})
# system defaultdict(<class 'int'>, {'2.txt': 1, '8.txt': 1, '5.txt': 1})
# use defaultdict(<class 'int'>, {'2.txt': 1, '9.txt': 1, '12.txt': 1, '7.txt': 1, '4.txt': 1})
# project defaultdict(<class 'int'>, {'2.txt': 1, '10.txt': 1, '8.txt': 1, '6.txt': 1, '3.txt': 1})
# means defaultdict(<class 'int'>, {'2.txt': 1})
# knowledge defaultdict(<class 'int'>, {'2.txt': 1, '9.txt': 1, '11.txt': 1, '10.txt': 1, '8.txt': 1, '6.txt': 1, '5.txt': 1, '4.txt': 1, '3.txt': 1})
# required defaultdict(<class 'int'>, {'2.txt': 1, '11.txt': 1, '6.txt': 1})
# evaluation defaultdict(<class 'int'>, {'2.txt': 1})
# focusing defaultdict(<class 'int'>, {'2.txt': 1, '12.txt': 1})
# develop defaultdict(<class 'int'>, {'2.txt': 1, '12.txt': 1, '6.txt': 1})
# architecture defaultdict(<class 'int'>, {'9.txt': 1})
# file defaultdict(<class 'int'>, {'9.txt': 1})
# internal defaultdict(<class 'int'>, {'9.txt': 1})
# different defaultdict(<class 'int'>, {'9.txt': 1, '11.txt': 1, '12.txt': 1, '8.txt': 1, '7.txt': 1, '6.txt': 1, '5.txt': 1, '3.txt': 1})
# appropriate defaultdict(<class 'int'>, {'9.txt': 1, '10.txt': 1, '3.txt': 1})
# ethical defaultdict(<class 'int'>, {'9.txt': 1})
# tools defaultdict(<class 'int'>, {'9.txt': 1, '10.txt': 1, '4.txt': 1, '3.txt': 1})
# crm defaultdict(<class 'int'>, {'9.txt': 1})
# process defaultdict(<class 'int'>, {'9.txt': 1, '10.txt': 1})
# decision defaultdict(<class 'int'>, {'9.txt': 1, '7.txt': 1})
# effectiveness defaultdict(<class 'int'>, {'9.txt': 1})
# businesses defaultdict(<class 'int'>, {'9.txt': 1, '12.txt': 1, '7.txt': 1})
# compare defaultdict(<class 'int'>, {'9.txt': 1, '12.txt': 1, '3.txt': 1})
# meet defaultdict(<class 'int'>, {'9.txt': 1})
# role defaultdict(<class 'int'>, {'9.txt': 1, '7.txt': 1, '4.txt': 1})
# used defaultdict(<class 'int'>, {'9.txt': 1})
# focuses defaultdict(<class 'int'>, {'9.txt': 1, '8.txt': 1, '3.txt': 1})
# help defaultdict(<class 'int'>, {'9.txt': 1, '10.txt': 1, '6.txt': 1, '3.txt': 1})
# networks defaultdict(<class 'int'>, {'9.txt': 1, '3.txt': 1})
# resources defaultdict(<class 'int'>, {'9.txt': 1})
# efficiency defaultdict(<class 'int'>, {'9.txt': 1})
# identify defaultdict(<class 'int'>, {'9.txt': 1, '11.txt': 1, '12.txt': 1, '8.txt': 1, '5.txt': 1, '3.txt': 1})
# establish defaultdict(<class 'int'>, {'9.txt': 1})
# operational defaultdict(<class 'int'>, {'9.txt': 1})
# strategy defaultdict(<class 'int'>, {'9.txt': 1, '4.txt': 1})
# analysis defaultdict(<class 'int'>, {'9.txt': 1, '6.txt': 1})
# examine defaultdict(<class 'int'>, {'9.txt': 1, '11.txt': 1, '7.txt': 1, '6.txt': 1, '4.txt': 1})
# protect defaultdict(<class 'int'>, {'9.txt': 1})
# addition defaultdict(<class 'int'>, {'9.txt': 1, '8.txt': 1})
# asset defaultdict(<class 'int'>, {'9.txt': 1})
# planning defaultdict(<class 'int'>, {'9.txt': 1, '10.txt': 1, '7.txt': 1})
# impacts defaultdict(<class 'int'>, {'9.txt': 1, '7.txt': 1})
# related defaultdict(<class 'int'>, {'9.txt': 1})
# mobile defaultdict(<class 'int'>, {'9.txt': 1})
# security defaultdict(<class 'int'>, {'9.txt': 1, '12.txt': 1, '8.txt': 1})
# managing defaultdict(<class 'int'>, {'9.txt': 1, '10.txt': 1})
# importance defaultdict(<class 'int'>, {'9.txt': 1, '8.txt': 1})
# computing defaultdict(<class 'int'>, {'9.txt': 1, '12.txt': 1})
# improving defaultdict(<class 'int'>, {'9.txt': 1})
# maintain defaultdict(<class 'int'>, {'9.txt': 1})
# covers defaultdict(<class 'int'>, {'9.txt': 1, '11.txt': 1, '12.txt': 1, '8.txt': 1})
# business defaultdict(<class 'int'>, {'9.txt': 1, '12.txt': 1, '7.txt': 1, '6.txt': 1, '4.txt': 1})
# dissemination defaultdict(<class 'int'>, {'9.txt': 1})
# analytics defaultdict(<class 'int'>, {'9.txt': 1, '4.txt': 1})
# selecting defaultdict(<class 'int'>, {'9.txt': 1})
# competitive defaultdict(<class 'int'>, {'9.txt': 1})
# competitiveness defaultdict(<class 'int'>, {'9.txt': 1})
# critique defaultdict(<class 'int'>, {'9.txt': 1})
# erp defaultdict(<class 'int'>, {'9.txt': 1})
# addressing defaultdict(<class 'int'>, {'9.txt': 1})
# weight defaultdict(<class 'int'>, {'9.txt': 1})
# criteria defaultdict(<class 'int'>, {'9.txt': 1, '12.txt': 1})
# controls defaultdict(<class 'int'>, {'9.txt': 1})
# ecommerce defaultdict(<class 'int'>, {'9.txt': 1})
# organizations defaultdict(<class 'int'>, {'9.txt': 1, '12.txt': 1, '10.txt': 1})
# strategic defaultdict(<class 'int'>, {'9.txt': 1})
# awareness defaultdict(<class 'int'>, {'9.txt': 1})
# value defaultdict(<class 'int'>, {'9.txt': 1})
# major defaultdict(<class 'int'>, {'9.txt': 1, '8.txt': 1})
# issues defaultdict(<class 'int'>, {'9.txt': 1})
# recognize defaultdict(<class 'int'>, {'9.txt': 1, '8.txt': 1, '5.txt': 1})
# needs defaultdict(<class 'int'>, {'9.txt': 1, '12.txt': 1})
# management defaultdict(<class 'int'>, {'9.txt': 1, '12.txt': 1, '10.txt': 1, '8.txt': 1})
# rights defaultdict(<class 'int'>, {'11.txt': 1})
# correlate defaultdict(<class 'int'>, {'11.txt': 1})
# skills defaultdict(<class 'int'>, {'11.txt': 1, '10.txt': 1, '8.txt': 1})
# communication defaultdict(<class 'int'>, {'11.txt': 1, '8.txt': 1})
# activities defaultdict(<class 'int'>, {'11.txt': 1})
# discuss defaultdict(<class 'int'>, {'11.txt': 1, '12.txt': 1, '8.txt': 1, '6.txt': 1})
# future defaultdict(<class 'int'>, {'11.txt': 1, '4.txt': 1})
# research defaultdict(<class 'int'>, {'11.txt': 1, '3.txt': 1})
# computer defaultdict(<class 'int'>, {'11.txt': 1, '3.txt': 1})
# best defaultdict(<class 'int'>, {'11.txt': 1, '7.txt': 1})
# papers defaultdict(<class 'int'>, {'11.txt': 1})
# styles defaultdict(<class 'int'>, {'11.txt': 1})
# methodologies defaultdict(<class 'int'>, {'11.txt': 1})
# discussions defaultdict(<class 'int'>, {'11.txt': 1})
# helps defaultdict(<class 'int'>, {'11.txt': 1, '10.txt': 1})
# link defaultdict(<class 'int'>, {'11.txt': 1})
# reviews defaultdict(<class 'int'>, {'11.txt': 1})
# write defaultdict(<class 'int'>, {'11.txt': 1})
# property defaultdict(<class 'int'>, {'11.txt': 1})
# summarize defaultdict(<class 'int'>, {'11.txt': 1})
# publishing defaultdict(<class 'int'>, {'11.txt': 1})
# methodology defaultdict(<class 'int'>, {'11.txt': 1})
# introduction defaultdict(<class 'int'>, {'11.txt': 1, '8.txt': 1})
# ethics defaultdict(<class 'int'>, {'11.txt': 1, '7.txt': 1})
# following defaultdict(<class 'int'>, {'11.txt': 1, '8.txt': 1, '6.txt': 1})
# technical defaultdict(<class 'int'>, {'11.txt': 1, '4.txt': 1})
# attributions defaultdict(<class 'int'>, {'11.txt': 1})
# audiences defaultdict(<class 'int'>, {'11.txt': 1})
# reading defaultdict(<class 'int'>, {'11.txt': 1})
# title defaultdict(<class 'int'>, {'11.txt': 1})
# attribution defaultdict(<class 'int'>, {'11.txt': 1})
# findings defaultdict(<class 'int'>, {'11.txt': 1})
# intellectual defaultdict(<class 'int'>, {'11.txt': 1})
# citation defaultdict(<class 'int'>, {'11.txt': 1})
# organization defaultdict(<class 'int'>, {'11.txt': 1, '10.txt': 1})
# paper defaultdict(<class 'int'>, {'11.txt': 1})
# abstract defaultdict(<class 'int'>, {'11.txt': 1})
# works defaultdict(<class 'int'>, {'11.txt': 1})
# article defaultdict(<class 'int'>, {'11.txt': 1})
# references defaultdict(<class 'int'>, {'11.txt': 1})
# parts defaultdict(<class 'int'>, {'11.txt': 1})
# literature defaultdict(<class 'int'>, {'11.txt': 1})
# review defaultdict(<class 'int'>, {'11.txt': 1, '8.txt': 1})
# preparing defaultdict(<class 'int'>, {'11.txt': 1})
# conclusion defaultdict(<class 'int'>, {'11.txt': 1})
# understand defaultdict(<class 'int'>, {'11.txt': 1, '3.txt': 1})
# results defaultdict(<class 'int'>, {'11.txt': 1, '6.txt': 1})
# conduct defaultdict(<class 'int'>, {'11.txt': 1})
# writing defaultdict(<class 'int'>, {'11.txt': 1})
# focus defaultdict(<class 'int'>, {'11.txt': 1})
# scientific defaultdict(<class 'int'>, {'11.txt': 1})
# practices defaultdict(<class 'int'>, {'11.txt': 1, '10.txt': 1, '7.txt': 1})
# technologies defaultdict(<class 'int'>, {'12.txt': 1, '7.txt': 1, '4.txt': 1, '3.txt': 1})
# affecting defaultdict(<class 'int'>, {'12.txt': 1})
# migrate defaultdict(<class 'int'>, {'12.txt': 1})
# trends defaultdict(<class 'int'>, {'12.txt': 1})
# variety defaultdict(<class 'int'>, {'12.txt': 1})
# overview defaultdict(<class 'int'>, {'12.txt': 1})
# would defaultdict(<class 'int'>, {'12.txt': 1})
# widely defaultdict(<class 'int'>, {'12.txt': 1})
# many defaultdict(<class 'int'>, {'12.txt': 1, '7.txt': 1, '6.txt': 1})
# server defaultdict(<class 'int'>, {'12.txt': 1})
# azure defaultdict(<class 'int'>, {'12.txt': 1})
# aws defaultdict(<class 'int'>, {'12.txt': 1})
# providers defaultdict(<class 'int'>, {'12.txt': 1})
# amazon defaultdict(<class 'int'>, {'12.txt': 1})
# cloud defaultdict(<class 'int'>, {'12.txt': 1, '8.txt': 1})
# present defaultdict(<class 'int'>, {'12.txt': 1, '6.txt': 1})
# across defaultdict(<class 'int'>, {'12.txt': 1})
# public defaultdict(<class 'int'>, {'12.txt': 1})
# selection defaultdict(<class 'int'>, {'12.txt': 1})
# scenarios defaultdict(<class 'int'>, {'12.txt': 1})
# specific defaultdict(<class 'int'>, {'12.txt': 1})
# handson defaultdict(<class 'int'>, {'12.txt': 1})
# virtualization defaultdict(<class 'int'>, {'12.txt': 1})
# select defaultdict(<class 'int'>, {'12.txt': 1})
# services defaultdict(<class 'int'>, {'12.txt': 1})
# adopted defaultdict(<class 'int'>, {'12.txt': 1})
# domains defaultdict(<class 'int'>, {'12.txt': 1, '3.txt': 1})
# service defaultdict(<class 'int'>, {'12.txt': 1})
# center defaultdict(<class 'int'>, {'12.txt': 1})
# top defaultdict(<class 'int'>, {'12.txt': 1})
# differences defaultdict(<class 'int'>, {'12.txt': 1})
# experience defaultdict(<class 'int'>, {'12.txt': 1, '3.txt': 1})
# infrastructures defaultdict(<class 'int'>, {'12.txt': 1})
# storage defaultdict(<class 'int'>, {'12.txt': 1})
# solution defaultdict(<class 'int'>, {'12.txt': 1, '6.txt': 1})
# utilizing defaultdict(<class 'int'>, {'12.txt': 1})
# vendor defaultdict(<class 'int'>, {'12.txt': 1})
# describe defaultdict(<class 'int'>, {'12.txt': 1})
# introduces defaultdict(<class 'int'>, {'12.txt': 1})
# functional defaultdict(<class 'int'>, {'12.txt': 1, '8.txt': 1})
# domain defaultdict(<class 'int'>, {'12.txt': 1, '5.txt': 1})
# microsoft defaultdict(<class 'int'>, {'12.txt': 1})
# pmi defaultdict(<class 'int'>, {'10.txt': 1})
# controllable defaultdict(<class 'int'>, {'10.txt': 1})
# sphere defaultdict(<class 'int'>, {'10.txt': 1})
# institutes defaultdict(<class 'int'>, {'10.txt': 1})
# body defaultdict(<class 'int'>, {'10.txt': 1})
# build defaultdict(<class 'int'>, {'10.txt': 1, '6.txt': 1})
# consider defaultdict(<class 'int'>, {'10.txt': 1})
# organized defaultdict(<class 'int'>, {'10.txt': 1})
# facilitate defaultdict(<class 'int'>, {'10.txt': 1})
# tasks defaultdict(<class 'int'>, {'10.txt': 1, '3.txt': 1})
# control defaultdict(<class 'int'>, {'10.txt': 1})
# innovative defaultdict(<class 'int'>, {'10.txt': 1, '7.txt': 1})
# employ defaultdict(<class 'int'>, {'10.txt': 1})
# global defaultdict(<class 'int'>, {'10.txt': 1})
# risk defaultdict(<class 'int'>, {'10.txt': 1})
# perspective defaultdict(<class 'int'>, {'10.txt': 1})
# software defaultdict(<class 'int'>, {'10.txt': 1})
# face defaultdict(<class 'int'>, {'10.txt': 1})
# theories defaultdict(<class 'int'>, {'10.txt': 1, '8.txt': 1})
# schedules defaultdict(<class 'int'>, {'10.txt': 1})
# sound defaultdict(<class 'int'>, {'10.txt': 1})
# scalable defaultdict(<class 'int'>, {'10.txt': 1})
# integrates defaultdict(<class 'int'>, {'10.txt': 1})
# manage defaultdict(<class 'int'>, {'10.txt': 1, '4.txt': 1})
# deliver defaultdict(<class 'int'>, {'10.txt': 1})
# complex defaultdict(<class 'int'>, {'10.txt': 1})
# pmbok defaultdict(<class 'int'>, {'10.txt': 1})
# leverage defaultdict(<class 'int'>, {'10.txt': 1})
# formulation defaultdict(<class 'int'>, {'10.txt': 1})
# guide defaultdict(<class 'int'>, {'10.txt': 1})
# based defaultdict(<class 'int'>, {'10.txt': 1, '3.txt': 1})
# plan defaultdict(<class 'int'>, {'10.txt': 1})
# mitigates defaultdict(<class 'int'>, {'10.txt': 1})
# interface defaultdict(<class 'int'>, {'8.txt': 1})
# combined defaultdict(<class 'int'>, {'8.txt': 1})
# ie defaultdict(<class 'int'>, {'8.txt': 1})
# world defaultdict(<class 'int'>, {'8.txt': 1, '6.txt': 1})
# describing defaultdict(<class 'int'>, {'8.txt': 1})
# core defaultdict(<class 'int'>, {'8.txt': 1, '7.txt': 1})
# physical defaultdict(<class 'int'>, {'8.txt': 1})
# real defaultdict(<class 'int'>, {'8.txt': 1, '6.txt': 1, '3.txt': 1})
# binding defaultdict(<class 'int'>, {'8.txt': 1})
# practical defaultdict(<class 'int'>, {'8.txt': 1, '6.txt': 1, '3.txt': 1})
# teaches defaultdict(<class 'int'>, {'8.txt': 1})
# strengthened defaultdict(<class 'int'>, {'8.txt': 1})
# able defaultdict(<class 'int'>, {'8.txt': 1})
# aspects defaultdict(<class 'int'>, {'8.txt': 1, '3.txt': 1})
# sensing defaultdict(<class 'int'>, {'8.txt': 1})
# areas defaultdict(<class 'int'>, {'8.txt': 1})
# specifications defaultdict(<class 'int'>, {'8.txt': 1})
# cyber defaultdict(<class 'int'>, {'8.txt': 1})
# protocols defaultdict(<class 'int'>, {'8.txt': 1})
# integration defaultdict(<class 'int'>, {'8.txt': 1})
# iot defaultdict(<class 'int'>, {'8.txt': 1})
# communications defaultdict(<class 'int'>, {'8.txt': 1})
# integrating defaultdict(<class 'int'>, {'8.txt': 1})
# actuation defaultdict(<class 'int'>, {'8.txt': 1})
# platforms defaultdict(<class 'int'>, {'8.txt': 1})
# iotbased defaultdict(<class 'int'>, {'8.txt': 1})
# complete defaultdict(<class 'int'>, {'8.txt': 1})
# popular defaultdict(<class 'int'>, {'8.txt': 1, '7.txt': 1})
# edge defaultdict(<class 'int'>, {'8.txt': 1})
# standards defaultdict(<class 'int'>, {'8.txt': 1})
# emphasis defaultdict(<class 'int'>, {'8.txt': 1})
# sensors defaultdict(<class 'int'>, {'8.txt': 1})
# gain defaultdict(<class 'int'>, {'8.txt': 1, '3.txt': 1})
# requirements defaultdict(<class 'int'>, {'8.txt': 1})
# things defaultdict(<class 'int'>, {'8.txt': 1})
# building defaultdict(<class 'int'>, {'8.txt': 1, '3.txt': 1})
# components defaultdict(<class 'int'>, {'8.txt': 1})
# program defaultdict(<class 'int'>, {'8.txt': 1})
# blocks defaultdict(<class 'int'>, {'8.txt': 1})
# industry defaultdict(<class 'int'>, {'8.txt': 1, '4.txt': 1})
# opportunities defaultdict(<class 'int'>, {'7.txt': 1})
# assess defaultdict(<class 'int'>, {'7.txt': 1, '4.txt': 1, '3.txt': 1})
# historical defaultdict(<class 'int'>, {'7.txt': 1})
# explore defaultdict(<class 'int'>, {'7.txt': 1})
# reasonably defaultdict(<class 'int'>, {'7.txt': 1})
# implementing defaultdict(<class 'int'>, {'7.txt': 1, '4.txt': 1})
# environment defaultdict(<class 'int'>, {'7.txt': 1})
# underlying defaultdict(<class 'int'>, {'7.txt': 1})
# recently defaultdict(<class 'int'>, {'7.txt': 1})
# dive defaultdict(<class 'int'>, {'7.txt': 1})
# nonfungible defaultdict(<class 'int'>, {'7.txt': 1})
# making defaultdict(<class 'int'>, {'7.txt': 1})
# nfts defaultdict(<class 'int'>, {'7.txt': 1})
# transformation defaultdict(<class 'int'>, {'7.txt': 1, '5.txt': 1})
# learn defaultdict(<class 'int'>, {'7.txt': 1, '3.txt': 1})
# take defaultdict(<class 'int'>, {'7.txt': 1})
# digital defaultdict(<class 'int'>, {'7.txt': 1})
# perspectives defaultdict(<class 'int'>, {'7.txt': 1})
# holds defaultdict(<class 'int'>, {'7.txt': 1})
# emerging defaultdict(<class 'int'>, {'7.txt': 1})
# define defaultdict(<class 'int'>, {'7.txt': 1, '4.txt': 1})
# metaverse defaultdict(<class 'int'>, {'7.txt': 1})
# tokens defaultdict(<class 'int'>, {'7.txt': 1})
# introductory defaultdict(<class 'int'>, {'7.txt': 1})
# cases defaultdict(<class 'int'>, {'7.txt': 1})
# concept defaultdict(<class 'int'>, {'7.txt': 1})
# industries defaultdict(<class 'int'>, {'7.txt': 1, '4.txt': 1})
# evolution defaultdict(<class 'int'>, {'7.txt': 1})
# deeper defaultdict(<class 'int'>, {'7.txt': 1})
# distinguish defaultdict(<class 'int'>, {'7.txt': 1, '4.txt': 1})
# insights defaultdict(<class 'int'>, {'7.txt': 1})
# people defaultdict(<class 'int'>, {'7.txt': 1})
# store defaultdict(<class 'int'>, {'7.txt': 1})
# conducting defaultdict(<class 'int'>, {'7.txt': 1})
# confused defaultdict(<class 'int'>, {'7.txt': 1})
# development defaultdict(<class 'int'>, {'7.txt': 1})
# execution defaultdict(<class 'int'>, {'7.txt': 1})
# purpose defaultdict(<class 'int'>, {'6.txt': 1})
# supervised defaultdict(<class 'int'>, {'6.txt': 1})
# programmatic defaultdict(<class 'int'>, {'6.txt': 1})
# along defaultdict(<class 'int'>, {'6.txt': 1})
# life defaultdict(<class 'int'>, {'6.txt': 1})
# mathematical defaultdict(<class 'int'>, {'6.txt': 1})
# programming defaultdict(<class 'int'>, {'6.txt': 1})
# discipline defaultdict(<class 'int'>, {'6.txt': 1})
# working defaultdict(<class 'int'>, {'6.txt': 1})
# cycle defaultdict(<class 'int'>, {'6.txt': 1})
# unsupervised defaultdict(<class 'int'>, {'6.txt': 1})
# mechanism defaultdict(<class 'int'>, {'6.txt': 1})
# intelligence defaultdict(<class 'int'>, {'6.txt': 1, '4.txt': 1, '3.txt': 1})
# abilities defaultdict(<class 'int'>, {'6.txt': 1})
# visualization defaultdict(<class 'int'>, {'6.txt': 1})
# machine defaultdict(<class 'int'>, {'6.txt': 1, '5.txt': 1, '4.txt': 1})
# applying defaultdict(<class 'int'>, {'6.txt': 1, '5.txt': 1})
# providing defaultdict(<class 'int'>, {'6.txt': 1})
# approach defaultdict(<class 'int'>, {'6.txt': 1})
# behind defaultdict(<class 'int'>, {'6.txt': 1, '3.txt': 1})
# statistical defaultdict(<class 'int'>, {'6.txt': 1})
# proficiency defaultdict(<class 'int'>, {'6.txt': 1})
# basic defaultdict(<class 'int'>, {'6.txt': 1, '3.txt': 1})
# validation defaultdict(<class 'int'>, {'6.txt': 1})
# linear defaultdict(<class 'int'>, {'5.txt': 1})
# spaces defaultdict(<class 'int'>, {'5.txt': 1})
# construction defaultdict(<class 'int'>, {'5.txt': 1})
# subspace defaultdict(<class 'int'>, {'5.txt': 1})
# vectors defaultdict(<class 'int'>, {'5.txt': 1})
# dependence defaultdict(<class 'int'>, {'5.txt': 1})
# bases defaultdict(<class 'int'>, {'5.txt': 1})
# norms defaultdict(<class 'int'>, {'5.txt': 1})
# dimension defaultdict(<class 'int'>, {'5.txt': 1})
# norm defaultdict(<class 'int'>, {'5.txt': 1})
# equation defaultdict(<class 'int'>, {'5.txt': 1})
# product defaultdict(<class 'int'>, {'5.txt': 1})
# distances defaultdict(<class 'int'>, {'5.txt': 1})
# vector defaultdict(<class 'int'>, {'5.txt': 1})
# properties defaultdict(<class 'int'>, {'5.txt': 1})
# independence defaultdict(<class 'int'>, {'5.txt': 1})
# mapping defaultdict(<class 'int'>, {'5.txt': 1})
# kernel defaultdict(<class 'int'>, {'5.txt': 1})
# basis defaultdict(<class 'int'>, {'5.txt': 1})
# orthogonal defaultdict(<class 'int'>, {'5.txt': 1})
# space defaultdict(<class 'int'>, {'5.txt': 1})
# eigenvalue defaultdict(<class 'int'>, {'5.txt': 1})
# matrix defaultdict(<class 'int'>, {'5.txt': 1})
# null defaultdict(<class 'int'>, {'5.txt': 1})
# length defaultdict(<class 'int'>, {'5.txt': 1})
# column defaultdict(<class 'int'>, {'5.txt': 1})
# range defaultdict(<class 'int'>, {'5.txt': 1})
# chain defaultdict(<class 'int'>, {'5.txt': 1})
# eigen defaultdict(<class 'int'>, {'5.txt': 1})
# decomposition defaultdict(<class 'int'>, {'5.txt': 1})
# applied defaultdict(<class 'int'>, {'5.txt': 1})
# image defaultdict(<class 'int'>, {'5.txt': 1})
# row defaultdict(<class 'int'>, {'5.txt': 1})
# matrices defaultdict(<class 'int'>, {'5.txt': 1})
# inner defaultdict(<class 'int'>, {'5.txt': 1})
# approximation defaultdict(<class 'int'>, {'5.txt': 1})
# markov defaultdict(<class 'int'>, {'5.txt': 1})
# equations defaultdict(<class 'int'>, {'5.txt': 1})
# complement defaultdict(<class 'int'>, {'5.txt': 1})
# relation defaultdict(<class 'int'>, {'5.txt': 1})
# rank defaultdict(<class 'int'>, {'5.txt': 1})
# affine defaultdict(<class 'int'>, {'5.txt': 1})
# orthogonality defaultdict(<class 'int'>, {'5.txt': 1})
# change defaultdict(<class 'int'>, {'5.txt': 1})
# phylogeny defaultdict(<class 'int'>, {'5.txt': 1})
# decompositions defaultdict(<class 'int'>, {'5.txt': 1})
# homogeneous defaultdict(<class 'int'>, {'5.txt': 1})
# found defaultdict(<class 'int'>, {'5.txt': 1})
# everevolving defaultdict(<class 'int'>, {'4.txt': 1})
# succeed defaultdict(<class 'int'>, {'4.txt': 1})
# aipowered defaultdict(<class 'int'>, {'4.txt': 1})
# advancements defaultdict(<class 'int'>, {'4.txt': 1})
# natural defaultdict(<class 'int'>, {'4.txt': 1, '3.txt': 1})
# deep defaultdict(<class 'int'>, {'4.txt': 1, '3.txt': 1})
# goal defaultdict(<class 'int'>, {'4.txt': 1})
# automation defaultdict(<class 'int'>, {'4.txt': 1})
# functions defaultdict(<class 'int'>, {'4.txt': 1})
# interested defaultdict(<class 'int'>, {'4.txt': 1})
# ai defaultdict(<class 'int'>, {'4.txt': 1})
# designed defaultdict(<class 'int'>, {'4.txt': 1})
# education defaultdict(<class 'int'>, {'4.txt': 1})
# artificial defaultdict(<class 'int'>, {'4.txt': 1, '3.txt': 1})
# acquiring defaultdict(<class 'int'>, {'4.txt': 1})
# training defaultdict(<class 'int'>, {'4.txt': 1})
# ensure defaultdict(<class 'int'>, {'4.txt': 1})
# latest defaultdict(<class 'int'>, {'4.txt': 1})
# approaches defaultdict(<class 'int'>, {'4.txt': 1})
# identifying defaultdict(<class 'int'>, {'4.txt': 1})
# big defaultdict(<class 'int'>, {'4.txt': 1})
# predictive defaultdict(<class 'int'>, {'4.txt': 1})
# optimize defaultdict(<class 'int'>, {'4.txt': 1})
# algorithmic defaultdict(<class 'int'>, {'4.txt': 1})
# right defaultdict(<class 'int'>, {'4.txt': 1})
# necessary defaultdict(<class 'int'>, {'4.txt': 1})
# comprehension defaultdict(<class 'int'>, {'4.txt': 1})
# workflows defaultdict(<class 'int'>, {'4.txt': 1})
# guides defaultdict(<class 'int'>, {'4.txt': 1})
# also defaultdict(<class 'int'>, {'3.txt': 1})
# learningbased defaultdict(<class 'int'>, {'3.txt': 1})
# foundations defaultdict(<class 'int'>, {'3.txt': 1})
# sets defaultdict(<class 'int'>, {'3.txt': 1})
# vision defaultdict(<class 'int'>, {'3.txt': 1})
# explain defaultdict(<class 'int'>, {'3.txt': 1})
# algorithms defaultdict(<class 'int'>, {'3.txt': 1})
# articles defaultdict(<class 'int'>, {'3.txt': 1})
# critically defaultdict(<class 'int'>, {'3.txt': 1})
# brain defaultdict(<class 'int'>, {'3.txt': 1})
# architectures defaultdict(<class 'int'>, {'3.txt': 1})
# tensorflow defaultdict(<class 'int'>, {'3.txt': 1})
# neural defaultdict(<class 'int'>, {'3.txt': 1})
# keras defaultdict(<class 'int'>, {'3.txt': 1})
# network defaultdict(<class 'int'>, {'3.txt': 1})
# modeling defaultdict(<class 'int'>, {'3.txt': 1})

# %%
for term, frequencies in term_doc_matrix.items():
  print(term,frequencies)

# %%
# Define a function to retrieve relevant documents for a given query
def retrieve_documents(query):
    query_tokens = preprocess_text(query)
    relevant_documents = set()
    for token in query_tokens:
        if token in term_doc_matrix:
            relevant_documents.update(term_doc_matrix[token].keys())
    return relevant_documents

# %%
# Example query
query = "semantic web"

# Retrieve relevant documents for the query
relevant_docs = retrieve_documents(query)

# Print the relevant documents
print("Relevant documents for the query:")
for doc in relevant_docs:
    print(doc)
# Out:
# Relevant documents for the query:
# 2.txt
# 12.txt
# 1.txt

# %% [markdown]
# ## Inverted Index Information Retrieval

# %%
# Initialize the inverted index dictionary and document frequency dictionary
inverted_index = defaultdict(list)
doc_freq = defaultdict(int)

# %%
# Loop through each file in the directory
for filename in os.listdir(directory):
    if filename.endswith(".txt"):
        file_path = os.path.join(directory, filename)
        with open(file_path, 'r') as file:
            text = file.read()
            # Preprocess the text
            preprocessed_tokens = preprocess_text(text)
            # Update the inverted index and document frequency
            for token in set(preprocessed_tokens):  # Ensure each term is counted once per document
                inverted_index[token].append(filename)
                doc_freq[token] += 1

# %%
# Print the inverted index
for term, documents in inverted_index.items():
    print(f"Term: {term}")
    print(f"Document Frequency: {doc_freq[term]}")
    print("Posting List:")
    for doc in documents:
        print(f" - {doc}")
    print()
# Out:
# Term: principles
# Document Frequency: 3
# Posting List:
#  - 1.txt
#  - 10.txt
#  - 3.txt
#
# Term: conceptualization
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: linked
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: demonstrations
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: within
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: schemas
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: processes
# Document Frequency: 4
# Posting List:
#  - 1.txt
#  - 9.txt
#  - 10.txt
#  - 4.txt
#
# Term: conversant
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: name
# Document Frequency: 12
# Posting List:
#  - 1.txt
#  - 2.txt
#  - 9.txt
#  - 11.txt
#  - 12.txt
#  - 10.txt
#  - 8.txt
#  - 7.txt
#  - 6.txt
#  - 5.txt
#  - 4.txt
#  - 3.txt
#
# Term: support
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: course
# Document Frequency: 12
# Posting List:
#  - 1.txt
#  - 2.txt
#  - 9.txt
#  - 11.txt
#  - 12.txt
#  - 10.txt
#  - 8.txt
#  - 7.txt
#  - 6.txt
#  - 5.txt
#  - 4.txt
#  - 3.txt
#
# Term: exploration
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: including
# Document Frequency: 2
# Posting List:
#  - 1.txt
#  - 9.txt
#
# Term: artifacts
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: databases
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: queries
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: outcomes
# Document Frequency: 12
# Posting List:
#  - 1.txt
#  - 2.txt
#  - 9.txt
#  - 11.txt
#  - 12.txt
#  - 10.txt
#  - 8.txt
#  - 7.txt
#  - 6.txt
#  - 5.txt
#  - 4.txt
#  - 3.txt
#
# Term: encompassing
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: functioning
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: thus
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: analogous
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: framework
# Document Frequency: 3
# Posting List:
#  - 1.txt
#  - 2.txt
#  - 4.txt
#
# Term: manner
# Document Frequency: 7
# Posting List:
#  - 1.txt
#  - 2.txt
#  - 11.txt
#  - 8.txt
#  - 6.txt
#  - 5.txt
#  - 3.txt
#
# Term: learning
# Document Frequency: 12
# Posting List:
#  - 1.txt
#  - 2.txt
#  - 9.txt
#  - 11.txt
#  - 12.txt
#  - 10.txt
#  - 8.txt
#  - 7.txt
#  - 6.txt
#  - 5.txt
#  - 4.txt
#  - 3.txt
#
# Term: internet
# Document Frequency: 3
# Posting List:
#  - 1.txt
#  - 8.txt
#  - 7.txt
#
# Term: disparate
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: foundational
# Document Frequency: 3
# Posting List:
#  - 1.txt
#  - 8.txt
#  - 3.txt
#
# Term: fundamental
# Document Frequency: 3
# Posting List:
#  - 1.txt
#  - 11.txt
#  - 5.txt
#
# Term: sparql
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: owl
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: construct
# Document Frequency: 2
# Posting List:
#  - 1.txt
#  - 10.txt
#
# Term: machines
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: interpret
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: impact
# Document Frequency: 3
# Posting List:
#  - 1.txt
#  - 9.txt
#  - 8.txt
#
# Term: become
# Document Frequency: 2
# Posting List:
#  - 1.txt
#  - 7.txt
#
# Term: ways
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: schema
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: applications
# Document Frequency: 5
# Posting List:
#  - 1.txt
#  - 12.txt
#  - 7.txt
#  - 6.txt
#  - 3.txt
#
# Term: effectively
# Document Frequency: 2
# Posting List:
#  - 1.txt
#  - 6.txt
#
# Term: ontology
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: structured
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: enabled
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: design
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: human
# Document Frequency: 2
# Posting List:
#  - 1.txt
#  - 3.txt
#
# Term: standard
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: understanding
# Document Frequency: 3
# Posting List:
#  - 1.txt
#  - 2.txt
#  - 6.txt
#
# Term: application
# Document Frequency: 4
# Posting List:
#  - 1.txt
#  - 6.txt
#  - 5.txt
#  - 4.txt
#
# Term: realworld
# Document Frequency: 5
# Posting List:
#  - 1.txt
#  - 2.txt
#  - 6.txt
#  - 5.txt
#  - 3.txt
#
# Term: better
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: sources
# Document Frequency: 2
# Posting List:
#  - 1.txt
#  - 11.txt
#
# Term: interoperability
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: retrieving
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: create
# Document Frequency: 3
# Posting List:
#  - 1.txt
#  - 10.txt
#  - 8.txt
#
# Term: concepts
# Document Frequency: 10
# Posting List:
#  - 1.txt
#  - 2.txt
#  - 11.txt
#  - 12.txt
#  - 10.txt
#  - 8.txt
#  - 7.txt
#  - 6.txt
#  - 5.txt
#  - 4.txt
#
# Term: plus
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: projects
# Document Frequency: 3
# Posting List:
#  - 1.txt
#  - 12.txt
#  - 10.txt
#
# Term: formulate
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: combining
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: translating
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: techniques
# Document Frequency: 5
# Posting List:
#  - 1.txt
#  - 9.txt
#  - 10.txt
#  - 8.txt
#  - 6.txt
#
# Term: data
# Document Frequency: 7
# Posting List:
#  - 1.txt
#  - 2.txt
#  - 9.txt
#  - 12.txt
#  - 6.txt
#  - 4.txt
#  - 3.txt
#
# Term: problems
# Document Frequency: 6
# Posting List:
#  - 1.txt
#  - 2.txt
#  - 10.txt
#  - 6.txt
#  - 5.txt
#  - 3.txt
#
# Term: elevated
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: utility
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: intricacies
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: resource
# Document Frequency: 2
# Posting List:
#  - 1.txt
#  - 9.txt
#
# Term: rdf
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: analyze
# Document Frequency: 2
# Posting List:
#  - 1.txt
#  - 7.txt
#
# Term: provides
# Document Frequency: 7
# Posting List:
#  - 1.txt
#  - 2.txt
#  - 11.txt
#  - 12.txt
#  - 10.txt
#  - 6.txt
#  - 5.txt
#
# Term: field
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: storing
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: semantic
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: query
# Document Frequency: 2
# Posting List:
#  - 1.txt
#  - 2.txt
#
# Term: finding
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: nuances
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: web
# Document Frequency: 3
# Posting List:
#  - 1.txt
#  - 2.txt
#  - 12.txt
#
# Term: ontologies
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: systems
# Document Frequency: 4
# Posting List:
#  - 1.txt
#  - 2.txt
#  - 9.txt
#  - 8.txt
#
# Term: using
# Document Frequency: 5
# Posting List:
#  - 1.txt
#  - 2.txt
#  - 10.txt
#  - 6.txt
#  - 3.txt
#
# Term: comprehensive
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: allowing
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: technology
# Document Frequency: 6
# Posting List:
#  - 1.txt
#  - 9.txt
#  - 10.txt
#  - 8.txt
#  - 7.txt
#  - 4.txt
#
# Term: students
# Document Frequency: 10
# Posting List:
#  - 1.txt
#  - 11.txt
#  - 12.txt
#  - 10.txt
#  - 8.txt
#  - 7.txt
#  - 6.txt
#  - 5.txt
#  - 4.txt
#  - 3.txt
#
# Term: address
# Document Frequency: 2
# Posting List:
#  - 1.txt
#  - 6.txt
#
# Term: language
# Document Frequency: 3
# Posting List:
#  - 1.txt
#  - 4.txt
#  - 3.txt
#
# Term: description
# Document Frequency: 1
# Posting List:
#  - 1.txt
#
# Term: relevant
# Document Frequency: 2
# Posting List:
#  - 1.txt
#  - 6.txt
#
# Term: information
# Document Frequency: 5
# Posting List:
#  - 1.txt
#  - 2.txt
#  - 9.txt
#  - 10.txt
#  - 8.txt
#
# Term: include
# Document Frequency: 3
# Posting List:
#  - 2.txt
#  - 9.txt
#  - 5.txt
#
# Term: advanced
# Document Frequency: 2
# Posting List:
#  - 2.txt
#  - 4.txt
#
# Term: models
# Document Frequency: 2
# Posting List:
#  - 2.txt
#  - 8.txt
#
# Term: relevance
# Document Frequency: 1
# Posting List:
#  - 2.txt
#
# Term: algebra
# Document Frequency: 2
# Posting List:
#  - 2.txt
#  - 5.txt
#
# Term: engines
# Document Frequency: 1
# Posting List:
#  - 2.txt
#
# Term: indexes
# Document Frequency: 1
# Posting List:
#  - 2.txt
#
# Term: acts
# Document Frequency: 1
# Posting List:
#  - 2.txt
#
# Term: processing
# Document Frequency: 3
# Posting List:
#  - 2.txt
#  - 4.txt
#  - 3.txt
#
# Term: theory
# Document Frequency: 1
# Posting List:
#  - 2.txt
#
# Term: various
# Document Frequency: 4
# Posting List:
#  - 2.txt
#  - 7.txt
#  - 4.txt
#  - 3.txt
#
# Term: procedures
# Document Frequency: 2
# Posting List:
#  - 2.txt
#  - 6.txt
#
# Term: topics
# Document Frequency: 6
# Posting List:
#  - 2.txt
#  - 9.txt
#  - 11.txt
#  - 12.txt
#  - 8.txt
#  - 6.txt
#
# Term: crawler
# Document Frequency: 1
# Posting List:
#  - 2.txt
#
# Term: science
# Document Frequency: 3
# Posting List:
#  - 2.txt
#  - 11.txt
#  - 6.txt
#
# Term: identification
# Document Frequency: 1
# Posting List:
#  - 2.txt
#
# Term: access
# Document Frequency: 1
# Posting List:
#  - 2.txt
#
# Term: aims
# Document Frequency: 1
# Posting List:
#  - 2.txt
#
# Term: case
# Document Frequency: 6
# Posting List:
#  - 2.txt
#  - 12.txt
#  - 8.txt
#  - 6.txt
#  - 5.txt
#  - 3.txt
#
# Term: solve
# Document Frequency: 5
# Posting List:
#  - 2.txt
#  - 10.txt
#  - 6.txt
#  - 5.txt
#  - 3.txt
#
# Term: broad
# Document Frequency: 2
# Posting List:
#  - 2.txt
#  - 6.txt
#
# Term: search
# Document Frequency: 1
# Posting List:
#  - 2.txt
#
# Term: implement
# Document Frequency: 3
# Posting List:
#  - 2.txt
#  - 8.txt
#  - 3.txt
#
# Term: document
# Document Frequency: 1
# Posting List:
#  - 2.txt
#
# Term: preprocessing
# Document Frequency: 1
# Posting List:
#  - 2.txt
#
# Term: implementation
# Document Frequency: 3
# Posting List:
#  - 2.txt
#  - 9.txt
#  - 10.txt
#
# Term: probability
# Document Frequency: 1
# Posting List:
#  - 2.txt
#
# Term: engine
# Document Frequency: 1
# Posting List:
#  - 2.txt
#
# Term: retrieval
# Document Frequency: 1
# Posting List:
#  - 2.txt
#
# Term: heart
# Document Frequency: 1
# Posting List:
#  - 2.txt
#
# Term: demonstrate
# Document Frequency: 8
# Posting List:
#  - 2.txt
#  - 9.txt
#  - 11.txt
#  - 8.txt
#  - 6.txt
#  - 5.txt
#  - 4.txt
#  - 3.txt
#
# Term: increasing
# Document Frequency: 1
# Posting List:
#  - 2.txt
#
# Term: types
# Document Frequency: 4
# Posting List:
#  - 2.txt
#  - 9.txt
#  - 11.txt
#  - 3.txt
#
# Term: solutions
# Document Frequency: 8
# Posting List:
#  - 2.txt
#  - 9.txt
#  - 12.txt
#  - 10.txt
#  - 8.txt
#  - 6.txt
#  - 5.txt
#  - 3.txt
#
# Term: methods
# Document Frequency: 5
# Posting List:
#  - 2.txt
#  - 11.txt
#  - 6.txt
#  - 4.txt
#  - 3.txt
#
# Term: covered
# Document Frequency: 2
# Posting List:
#  - 2.txt
#  - 6.txt
#
# Term: evaluate
# Document Frequency: 4
# Posting List:
#  - 2.txt
#  - 9.txt
#  - 12.txt
#  - 3.txt
#
# Term: ranking
# Document Frequency: 1
# Posting List:
#  - 2.txt
#
# Term: probabilistic
# Document Frequency: 1
# Posting List:
#  - 2.txt
#
# Term: structure
# Document Frequency: 2
# Posting List:
#  - 2.txt
#  - 11.txt
#
# Term: apply
# Document Frequency: 8
# Posting List:
#  - 2.txt
#  - 12.txt
#  - 10.txt
#  - 8.txt
#  - 7.txt
#  - 6.txt
#  - 5.txt
#  - 3.txt
#
# Term: professional
# Document Frequency: 6
# Posting List:
#  - 2.txt
#  - 11.txt
#  - 8.txt
#  - 6.txt
#  - 5.txt
#  - 3.txt
#
# Term: ir
# Document Frequency: 1
# Posting List:
#  - 2.txt
#
# Term: basics
# Document Frequency: 2
# Posting List:
#  - 2.txt
#  - 7.txt
#
# Term: system
# Document Frequency: 3
# Posting List:
#  - 2.txt
#  - 8.txt
#  - 5.txt
#
# Term: use
# Document Frequency: 5
# Posting List:
#  - 2.txt
#  - 9.txt
#  - 12.txt
#  - 7.txt
#  - 4.txt
#
# Term: project
# Document Frequency: 5
# Posting List:
#  - 2.txt
#  - 10.txt
#  - 8.txt
#  - 6.txt
#  - 3.txt
#
# Term: means
# Document Frequency: 1
# Posting List:
#  - 2.txt
#
# Term: knowledge
# Document Frequency: 9
# Posting List:
#  - 2.txt
#  - 9.txt
#  - 11.txt
#  - 10.txt
#  - 8.txt
#  - 6.txt
#  - 5.txt
#  - 4.txt
#  - 3.txt
#
# Term: required
# Document Frequency: 3
# Posting List:
#  - 2.txt
#  - 11.txt
#  - 6.txt
#
# Term: evaluation
# Document Frequency: 1
# Posting List:
#  - 2.txt
#
# Term: focusing
# Document Frequency: 2
# Posting List:
#  - 2.txt
#  - 12.txt
#
# Term: develop
# Document Frequency: 3
# Posting List:
#  - 2.txt
#  - 12.txt
#  - 6.txt
#
# Term: architecture
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: file
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: internal
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: different
# Document Frequency: 8
# Posting List:
#  - 9.txt
#  - 11.txt
#  - 12.txt
#  - 8.txt
#  - 7.txt
#  - 6.txt
#  - 5.txt
#  - 3.txt
#
# Term: appropriate
# Document Frequency: 3
# Posting List:
#  - 9.txt
#  - 10.txt
#  - 3.txt
#
# Term: ethical
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: tools
# Document Frequency: 4
# Posting List:
#  - 9.txt
#  - 10.txt
#  - 4.txt
#  - 3.txt
#
# Term: crm
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: process
# Document Frequency: 2
# Posting List:
#  - 9.txt
#  - 10.txt
#
# Term: decision
# Document Frequency: 2
# Posting List:
#  - 9.txt
#  - 7.txt
#
# Term: effectiveness
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: businesses
# Document Frequency: 3
# Posting List:
#  - 9.txt
#  - 12.txt
#  - 7.txt
#
# Term: compare
# Document Frequency: 3
# Posting List:
#  - 9.txt
#  - 12.txt
#  - 3.txt
#
# Term: meet
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: role
# Document Frequency: 3
# Posting List:
#  - 9.txt
#  - 7.txt
#  - 4.txt
#
# Term: used
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: focuses
# Document Frequency: 3
# Posting List:
#  - 9.txt
#  - 8.txt
#  - 3.txt
#
# Term: help
# Document Frequency: 4
# Posting List:
#  - 9.txt
#  - 10.txt
#  - 6.txt
#  - 3.txt
#
# Term: networks
# Document Frequency: 2
# Posting List:
#  - 9.txt
#  - 3.txt
#
# Term: resources
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: efficiency
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: identify
# Document Frequency: 6
# Posting List:
#  - 9.txt
#  - 11.txt
#  - 12.txt
#  - 8.txt
#  - 5.txt
#  - 3.txt
#
# Term: establish
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: operational
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: strategy
# Document Frequency: 2
# Posting List:
#  - 9.txt
#  - 4.txt
#
# Term: analysis
# Document Frequency: 2
# Posting List:
#  - 9.txt
#  - 6.txt
#
# Term: examine
# Document Frequency: 5
# Posting List:
#  - 9.txt
#  - 11.txt
#  - 7.txt
#  - 6.txt
#  - 4.txt
#
# Term: protect
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: addition
# Document Frequency: 2
# Posting List:
#  - 9.txt
#  - 8.txt
#
# Term: asset
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: planning
# Document Frequency: 3
# Posting List:
#  - 9.txt
#  - 10.txt
#  - 7.txt
#
# Term: impacts
# Document Frequency: 2
# Posting List:
#  - 9.txt
#  - 7.txt
#
# Term: related
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: mobile
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: security
# Document Frequency: 3
# Posting List:
#  - 9.txt
#  - 12.txt
#  - 8.txt
#
# Term: managing
# Document Frequency: 2
# Posting List:
#  - 9.txt
#  - 10.txt
#
# Term: importance
# Document Frequency: 2
# Posting List:
#  - 9.txt
#  - 8.txt
#
# Term: computing
# Document Frequency: 2
# Posting List:
#  - 9.txt
#  - 12.txt
#
# Term: improving
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: maintain
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: covers
# Document Frequency: 4
# Posting List:
#  - 9.txt
#  - 11.txt
#  - 12.txt
#  - 8.txt
#
# Term: business
# Document Frequency: 5
# Posting List:
#  - 9.txt
#  - 12.txt
#  - 7.txt
#  - 6.txt
#  - 4.txt
#
# Term: dissemination
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: analytics
# Document Frequency: 2
# Posting List:
#  - 9.txt
#  - 4.txt
#
# Term: selecting
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: competitive
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: competitiveness
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: critique
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: erp
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: addressing
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: weight
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: criteria
# Document Frequency: 2
# Posting List:
#  - 9.txt
#  - 12.txt
#
# Term: controls
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: ecommerce
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: organizations
# Document Frequency: 3
# Posting List:
#  - 9.txt
#  - 12.txt
#  - 10.txt
#
# Term: strategic
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: awareness
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: value
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: major
# Document Frequency: 2
# Posting List:
#  - 9.txt
#  - 8.txt
#
# Term: issues
# Document Frequency: 1
# Posting List:
#  - 9.txt
#
# Term: recognize
# Document Frequency: 3
# Posting List:
#  - 9.txt
#  - 8.txt
#  - 5.txt
#
# Term: needs
# Document Frequency: 2
# Posting List:
#  - 9.txt
#  - 12.txt
#
# Term: management
# Document Frequency: 4
# Posting List:
#  - 9.txt
#  - 12.txt
#  - 10.txt
#  - 8.txt
#
# Term: rights
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: correlate
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: skills
# Document Frequency: 3
# Posting List:
#  - 11.txt
#  - 10.txt
#  - 8.txt
#
# Term: communication
# Document Frequency: 2
# Posting List:
#  - 11.txt
#  - 8.txt
#
# Term: activities
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: discuss
# Document Frequency: 4
# Posting List:
#  - 11.txt
#  - 12.txt
#  - 8.txt
#  - 6.txt
#
# Term: future
# Document Frequency: 2
# Posting List:
#  - 11.txt
#  - 4.txt
#
# Term: research
# Document Frequency: 2
# Posting List:
#  - 11.txt
#  - 3.txt
#
# Term: computer
# Document Frequency: 2
# Posting List:
#  - 11.txt
#  - 3.txt
#
# Term: best
# Document Frequency: 2
# Posting List:
#  - 11.txt
#  - 7.txt
#
# Term: papers
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: styles
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: methodologies
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: discussions
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: helps
# Document Frequency: 2
# Posting List:
#  - 11.txt
#  - 10.txt
#
# Term: link
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: reviews
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: write
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: property
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: summarize
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: publishing
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: methodology
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: introduction
# Document Frequency: 2
# Posting List:
#  - 11.txt
#  - 8.txt
#
# Term: ethics
# Document Frequency: 2
# Posting List:
#  - 11.txt
#  - 7.txt
#
# Term: following
# Document Frequency: 3
# Posting List:
#  - 11.txt
#  - 8.txt
#  - 6.txt
#
# Term: technical
# Document Frequency: 2
# Posting List:
#  - 11.txt
#  - 4.txt
#
# Term: attributions
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: audiences
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: reading
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: title
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: attribution
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: findings
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: intellectual
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: citation
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: organization
# Document Frequency: 2
# Posting List:
#  - 11.txt
#  - 10.txt
#
# Term: paper
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: abstract
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: works
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: article
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: references
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: parts
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: literature
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: review
# Document Frequency: 2
# Posting List:
#  - 11.txt
#  - 8.txt
#
# Term: preparing
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: conclusion
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: understand
# Document Frequency: 2
# Posting List:
#  - 11.txt
#  - 3.txt
#
# Term: results
# Document Frequency: 2
# Posting List:
#  - 11.txt
#  - 6.txt
#
# Term: conduct
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: writing
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: focus
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: scientific
# Document Frequency: 1
# Posting List:
#  - 11.txt
#
# Term: practices
# Document Frequency: 3
# Posting List:
#  - 11.txt
#  - 10.txt
#  - 7.txt
#
# Term: technologies
# Document Frequency: 4
# Posting List:
#  - 12.txt
#  - 7.txt
#  - 4.txt
#  - 3.txt
#
# Term: affecting
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: migrate
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: trends
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: variety
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: overview
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: would
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: widely
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: many
# Document Frequency: 3
# Posting List:
#  - 12.txt
#  - 7.txt
#  - 6.txt
#
# Term: server
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: azure
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: aws
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: providers
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: amazon
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: cloud
# Document Frequency: 2
# Posting List:
#  - 12.txt
#  - 8.txt
#
# Term: present
# Document Frequency: 2
# Posting List:
#  - 12.txt
#  - 6.txt
#
# Term: across
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: public
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: selection
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: scenarios
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: specific
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: handson
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: virtualization
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: select
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: services
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: adopted
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: domains
# Document Frequency: 2
# Posting List:
#  - 12.txt
#  - 3.txt
#
# Term: service
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: center
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: top
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: differences
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: experience
# Document Frequency: 2
# Posting List:
#  - 12.txt
#  - 3.txt
#
# Term: infrastructures
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: storage
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: solution
# Document Frequency: 2
# Posting List:
#  - 12.txt
#  - 6.txt
#
# Term: utilizing
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: vendor
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: describe
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: introduces
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: functional
# Document Frequency: 2
# Posting List:
#  - 12.txt
#  - 8.txt
#
# Term: domain
# Document Frequency: 2
# Posting List:
#  - 12.txt
#  - 5.txt
#
# Term: microsoft
# Document Frequency: 1
# Posting List:
#  - 12.txt
#
# Term: pmi
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: controllable
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: sphere
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: institutes
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: body
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: build
# Document Frequency: 2
# Posting List:
#  - 10.txt
#  - 6.txt
#
# Term: consider
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: organized
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: facilitate
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: tasks
# Document Frequency: 2
# Posting List:
#  - 10.txt
#  - 3.txt
#
# Term: control
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: innovative
# Document Frequency: 2
# Posting List:
#  - 10.txt
#  - 7.txt
#
# Term: employ
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: global
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: risk
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: perspective
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: software
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: face
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: theories
# Document Frequency: 2
# Posting List:
#  - 10.txt
#  - 8.txt
#
# Term: schedules
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: sound
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: scalable
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: integrates
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: manage
# Document Frequency: 2
# Posting List:
#  - 10.txt
#  - 4.txt
#
# Term: deliver
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: complex
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: pmbok
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: leverage
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: formulation
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: guide
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: based
# Document Frequency: 2
# Posting List:
#  - 10.txt
#  - 3.txt
#
# Term: plan
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: mitigates
# Document Frequency: 1
# Posting List:
#  - 10.txt
#
# Term: interface
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: combined
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: ie
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: world
# Document Frequency: 2
# Posting List:
#  - 8.txt
#  - 6.txt
#
# Term: describing
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: core
# Document Frequency: 2
# Posting List:
#  - 8.txt
#  - 7.txt
#
# Term: physical
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: real
# Document Frequency: 3
# Posting List:
#  - 8.txt
#  - 6.txt
#  - 3.txt
#
# Term: binding
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: practical
# Document Frequency: 3
# Posting List:
#  - 8.txt
#  - 6.txt
#  - 3.txt
#
# Term: teaches
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: strengthened
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: able
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: aspects
# Document Frequency: 2
# Posting List:
#  - 8.txt
#  - 3.txt
#
# Term: sensing
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: areas
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: specifications
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: cyber
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: protocols
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: integration
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: iot
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: communications
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: integrating
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: actuation
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: platforms
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: iotbased
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: complete
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: popular
# Document Frequency: 2
# Posting List:
#  - 8.txt
#  - 7.txt
#
# Term: edge
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: standards
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: emphasis
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: sensors
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: gain
# Document Frequency: 2
# Posting List:
#  - 8.txt
#  - 3.txt
#
# Term: requirements
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: things
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: building
# Document Frequency: 2
# Posting List:
#  - 8.txt
#  - 3.txt
#
# Term: components
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: program
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: blocks
# Document Frequency: 1
# Posting List:
#  - 8.txt
#
# Term: industry
# Document Frequency: 2
# Posting List:
#  - 8.txt
#  - 4.txt
#
# Term: opportunities
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: assess
# Document Frequency: 3
# Posting List:
#  - 7.txt
#  - 4.txt
#  - 3.txt
#
# Term: historical
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: explore
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: reasonably
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: implementing
# Document Frequency: 2
# Posting List:
#  - 7.txt
#  - 4.txt
#
# Term: environment
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: underlying
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: recently
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: dive
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: nonfungible
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: making
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: nfts
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: transformation
# Document Frequency: 2
# Posting List:
#  - 7.txt
#  - 5.txt
#
# Term: learn
# Document Frequency: 2
# Posting List:
#  - 7.txt
#  - 3.txt
#
# Term: take
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: digital
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: perspectives
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: holds
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: emerging
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: define
# Document Frequency: 2
# Posting List:
#  - 7.txt
#  - 4.txt
#
# Term: metaverse
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: tokens
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: introductory
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: cases
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: concept
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: industries
# Document Frequency: 2
# Posting List:
#  - 7.txt
#  - 4.txt
#
# Term: evolution
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: deeper
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: distinguish
# Document Frequency: 2
# Posting List:
#  - 7.txt
#  - 4.txt
#
# Term: insights
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: people
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: store
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: conducting
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: confused
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: development
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: execution
# Document Frequency: 1
# Posting List:
#  - 7.txt
#
# Term: purpose
# Document Frequency: 1
# Posting List:
#  - 6.txt
#
# Term: supervised
# Document Frequency: 1
# Posting List:
#  - 6.txt
#
# Term: programmatic
# Document Frequency: 1
# Posting List:
#  - 6.txt
#
# Term: along
# Document Frequency: 1
# Posting List:
#  - 6.txt
#
# Term: life
# Document Frequency: 1
# Posting List:
#  - 6.txt
#
# Term: mathematical
# Document Frequency: 1
# Posting List:
#  - 6.txt
#
# Term: programming
# Document Frequency: 1
# Posting List:
#  - 6.txt
#
# Term: discipline
# Document Frequency: 1
# Posting List:
#  - 6.txt
#
# Term: working
# Document Frequency: 1
# Posting List:
#  - 6.txt
#
# Term: cycle
# Document Frequency: 1
# Posting List:
#  - 6.txt
#
# Term: unsupervised
# Document Frequency: 1
# Posting List:
#  - 6.txt
#
# Term: mechanism
# Document Frequency: 1
# Posting List:
#  - 6.txt
#
# Term: intelligence
# Document Frequency: 3
# Posting List:
#  - 6.txt
#  - 4.txt
#  - 3.txt
#
# Term: abilities
# Document Frequency: 1
# Posting List:
#  - 6.txt
#
# Term: visualization
# Document Frequency: 1
# Posting List:
#  - 6.txt
#
# Term: machine
# Document Frequency: 3
# Posting List:
#  - 6.txt
#  - 5.txt
#  - 4.txt
#
# Term: applying
# Document Frequency: 2
# Posting List:
#  - 6.txt
#  - 5.txt
#
# Term: providing
# Document Frequency: 1
# Posting List:
#  - 6.txt
#
# Term: approach
# Document Frequency: 1
# Posting List:
#  - 6.txt
#
# Term: behind
# Document Frequency: 2
# Posting List:
#  - 6.txt
#  - 3.txt
#
# Term: statistical
# Document Frequency: 1
# Posting List:
#  - 6.txt
#
# Term: proficiency
# Document Frequency: 1
# Posting List:
#  - 6.txt
#
# Term: basic
# Document Frequency: 2
# Posting List:
#  - 6.txt
#  - 3.txt
#
# Term: validation
# Document Frequency: 1
# Posting List:
#  - 6.txt
#
# Term: linear
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: spaces
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: construction
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: subspace
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: vectors
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: dependence
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: bases
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: norms
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: dimension
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: norm
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: equation
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: product
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: distances
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: vector
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: properties
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: independence
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: mapping
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: kernel
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: basis
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: orthogonal
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: space
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: eigenvalue
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: matrix
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: null
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: length
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: column
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: range
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: chain
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: eigen
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: decomposition
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: applied
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: image
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: row
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: matrices
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: inner
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: approximation
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: markov
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: equations
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: complement
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: relation
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: rank
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: affine
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: orthogonality
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: change
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: phylogeny
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: decompositions
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: homogeneous
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: found
# Document Frequency: 1
# Posting List:
#  - 5.txt
#
# Term: everevolving
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: succeed
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: aipowered
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: advancements
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: natural
# Document Frequency: 2
# Posting List:
#  - 4.txt
#  - 3.txt
#
# Term: deep
# Document Frequency: 2
# Posting List:
#  - 4.txt
#  - 3.txt
#
# Term: goal
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: automation
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: functions
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: interested
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: ai
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: designed
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: education
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: artificial
# Document Frequency: 2
# Posting List:
#  - 4.txt
#  - 3.txt
#
# Term: acquiring
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: training
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: ensure
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: latest
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: approaches
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: identifying
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: big
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: predictive
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: optimize
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: algorithmic
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: right
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: necessary
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: comprehension
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: workflows
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: guides
# Document Frequency: 1
# Posting List:
#  - 4.txt
#
# Term: also
# Document Frequency: 1
# Posting List:
#  - 3.txt
#
# Term: learningbased
# Document Frequency: 1
# Posting List:
#  - 3.txt
#
# Term: foundations
# Document Frequency: 1
# Posting List:
#  - 3.txt
#
# Term: sets
# Document Frequency: 1
# Posting List:
#  - 3.txt
#
# Term: vision
# Document Frequency: 1
# Posting List:
#  - 3.txt
#
# Term: explain
# Document Frequency: 1
# Posting List:
#  - 3.txt
#
# Term: algorithms
# Document Frequency: 1
# Posting List:
#  - 3.txt
#
# Term: articles
# Document Frequency: 1
# Posting List:
#  - 3.txt
#
# Term: critically
# Document Frequency: 1
# Posting List:
#  - 3.txt
#
# Term: brain
# Document Frequency: 1
# Posting List:
#  - 3.txt
#
# Term: architectures
# Document Frequency: 1
# Posting List:
#  - 3.txt
#
# Term: tensorflow
# Document Frequency: 1
# Posting List:
#  - 3.txt
#
# Term: neural
# Document Frequency: 1
# Posting List:
#  - 3.txt
#
# Term: keras
# Document Frequency: 1
# Posting List:
#  - 3.txt
#
# Term: network
# Document Frequency: 1
# Posting List:
#  - 3.txt
#
# Term: modeling
# Document Frequency: 1
# Posting List:
#  - 3.txt

# %% [markdown]
# ## Vector Space Model

# %% [markdown]
# ## BM25 Model Implementation

# %% [markdown]
# ### BM25Okapi Understanding

# %%
# !pip install rank_bm25
# Out:
# Requirement already satisfied: rank_bm25 in /usr/local/lib/python3.10/dist-packages (0.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rank_bm25) (1.25.2)

# %%
from rank_bm25 import BM25Okapi

# %%
corpus = [
    "Hello there good man!",
    "It is quite windy in London",
    "How is the weather today?"
]

# %%
tokenized_corpus = [doc.split(" ") for doc in corpus]

# %%
tokenized_doc = [doc.split() for doc in corpus]
tokenized_doc
# Out:
# [['Hello', 'there', 'good', 'man!'],
#  ['It', 'is', 'quite', 'windy', 'in', 'London'],
#  ['How', 'is', 'the', 'weather', 'today?']]

# %%
tokenized_corpus = []
for doc in corpus:
  print(doc)
  tokenized_doc = doc.split()
  tokenized_corpus.append(tokenized_doc)
# Out:
# Hello there good man!
# It is quite windy in London
# How is the weather today?

# %%
tokenized_corpus
# Out:
# [['Hello', 'there', 'good', 'man!'],
#  ['It', 'is', 'quite', 'windy', 'in', 'London'],
#  ['How', 'is', 'the', 'weather', 'today?']]

# %%
bm25 = BM25Okapi(tokenized_corpus)

# %%
query = "windy London"
tokenized_query = query.split(" ")

doc_scores = bm25.get_scores(tokenized_query)
doc_scores
# Out:
# array([0.        , 0.93729472, 0.        ])

# %%
bm25.get_top_n(tokenized_query, corpus, n=1)
# Out:
# ['It is quite windy in London']

# %%
## Implementation starts from here

# %% [markdown]
# ### Model Implementation

# %%
# !pip install rank_bm25
# Out:
# Requirement already satisfied: rank_bm25 in /usr/local/lib/python3.10/dist-packages (0.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rank_bm25) (1.25.2)

# %%
from rank_bm25 import BM25Okapi

# %%
# Initialize a list to store preprocessed documents
preprocessed_docs = []

# %%
# Loop through each file in the directory and preprocess the text
for filename in os.listdir(directory):
    if filename.endswith(".txt"):
        file_path = os.path.join(directory, filename)
        with open(file_path, 'r') as file:
            text = file.read()
            preprocessed_docs.append(preprocess_text(text))

# %%
# Initialize BM25 model with preprocessed documents
bm25 = BM25Okapi(preprocessed_docs)

# %%
# Define a function to retrieve documents using BM25
def retrieve_documents(query):
    preprocessed_query = preprocess_text(query)
    scores = bm25.get_scores(preprocessed_query)
    ranked_results = sorted(zip(range(len(scores)), scores), key=lambda x: x[1], reverse=True)[:3]
    return ranked_results

# %%
# Example query
# Ask the user to input a query
query = input("Enter your query: ")

# Retrieve documents using BM25
ranked_documents = retrieve_documents(query)

# Print the ranked documents with filenames and the first line of content
print("Ranked Documents:")
for idx, score in ranked_documents:
    filename = os.listdir(directory)[idx]  # Get the filename corresponding to the document index
    with open(os.path.join(directory, filename), 'r') as file:
        first_line = file.readline()  # Read the first line of the file
    print(f"Document: {filename}, Score = {score}")
    print("Document Title:")
    print(first_line)
    print()
# Out:
# Enter your query: Information retrieval
# Ranked Documents:
# Document: 2.txt, Score = 5.0262308127905095
# Document Title:
# Course Name: Information Retrieval
#
#
# Document: 9.txt, Score = 0.6585459046837796
# Document Title:
# Course Name: Managing Information Systems & Technology
#
#
# Document: 10.txt, Score = 0.6239200766356894
# Document Title:
# Course Name: Information Technology Project Management

# %% [markdown]
# ### Relevance feedback and query expansion for BM25 Okapi

# %% [markdown]
# ## Evaluate the performance of the OkapiB25 Model

# %%
import pandas as pd
import numpy as np

# %%
def precision_at_k(relevant_docs, retrieved_docs, k):
    relevant_docs_at_k = relevant_docs.intersection(retrieved_docs[:k])
    return len(relevant_docs_at_k) / k if k > 0 else 0

def recall_at_k(relevant_docs, retrieved_docs, k):
    relevant_docs_at_k = relevant_docs.intersection(retrieved_docs[:k])
    return len(relevant_docs_at_k) / len(relevant_docs) if len(relevant_docs) > 0 else 0

# def average_precision(relevant_docs, retrieved_docs):
#     ap = 0
#     num_relevant_docs = len(relevant_docs)
#     num_retrieved_docs = len(retrieved_docs)
#     for k in range(1, num_retrieved_docs + 1):
#         if retrieved_docs[k - 1] in relevant_docs:
#             ap += precision_at_k(relevant_docs, retrieved_docs, k)
#     return ap / min(num_relevant_docs, num_retrieved_docs)
def average_precision(relevant_docs, retrieved_docs):
    ap = 0
    num_relevant_docs = len(relevant_docs)
    num_retrieved_docs = len(retrieved_docs)
    if num_relevant_docs == 0 or num_retrieved_docs == 0:
        return 0  # Avoid division by zero
    for k in range(1, num_retrieved_docs + 1):
        if retrieved_docs[k - 1] in relevant_docs:
            ap += precision_at_k(relevant_docs, retrieved_docs, k)
    return ap / min(num_relevant_docs, num_retrieved_docs)


def mean_average_precision(relevance_data):
    map_scores = []
    for query_id, group in relevance_data.groupby('query'):
        relevant_docs = set(group[group['relevance'] == 1]['document'])
        retrieved_docs = list(group['document'])
        ap = average_precision(relevant_docs, retrieved_docs)
        map_scores.append(ap)
    return np.mean(map_scores)

def dcg(relevance, k):
    dcg_score = 0
    for i in range(min(k, len(relevance))):
        dcg_score += (2 ** relevance[i] - 1) / np.log2(i + 2)
    return dcg_score

def ndcg_at_k(relevance, k):
    sorted_relevance = sorted(relevance, reverse=True)
    ideal_dcg = dcg(sorted_relevance, k)
    actual_dcg = dcg(relevance, k)
    return actual_dcg / ideal_dcg if ideal_dcg > 0 else 0

# %%
# Load ground truth data
file_path = "/content/drive/MyDrive/MscIT/3rd Trimester/6th Session/AIM 600 Information Retreival - Siman Giri/Week 4 Assignment/IR Assignment/Relevance Data/Relevance Document - Relevance document.csv"
ground_truth_df = pd.read_csv(file_path)

# %%
ground_truth_df.drop(['Not needed'], axis=1, inplace = True)

# %%
ground_truth_df
# Out:
#                                                 query document  relevance
# 0                              Semantic Web Technolog    1.txt          1
# 1                        Information retrieval System    1.txt          0
# 2   RDF (Resource Description Framework), RDF Sche...    1.txt          1
# 3        ontologies using Web Ontology Language (OWL)    1.txt          1
# 4                          Convolution neural network    1.txt          0
# 5                               Information Retrieval    2.txt          1
# 6   document pre-processing and identification of ...    2.txt          1
# 7                          Convolution neural network    2.txt          0
# 8                          derivative and integration    2.txt          0
# 9         Artificial Neural Network and Deep Learning    3.txt          1
# 10  basic principles behind neural networks and de...    3.txt          1
# 11  practical experience in building neural networ...    3.txt          1
# 12                              Information Retrieval    3.txt          0
# 13                              Web Ontology Language    3.txt          0
# 14         Artificial Intelligence & Machine Learning    3.txt          1
# 15  latest advancements and technical approaches i...    4.txt          1
# 16                                    Learning Python    4.txt          0
# 17                     Programming Language practical    4.txt          0
# 18                                Basic Math Learning    4.txt          0

# %%
# Compute evaluation metrics
precision_5 = []
recall_5 = []
map_score = mean_average_precision(ground_truth_df)
ndcg_5 = []

# %%
for query_id, group in ground_truth_df.groupby('query'):
    relevant_docs = set(group[group['relevance'] == 1]['document'])
    retrieved_docs = list(group['document'])

    precision_5.append(precision_at_k(relevant_docs, retrieved_docs, 5))
    recall_5.append(recall_at_k(relevant_docs, retrieved_docs, 5))

    # Extract relevance scores and convert them to individual scores
    relevance_scores = list(group['relevance'])
    relevance_scores_individual = [1 if score == 1 else 0 for score in relevance_scores]

    ndcg_5.append(ndcg_at_k(relevance_scores_individual, 5))

precision_5_mean = np.mean(precision_5)
recall_5_mean = np.mean(recall_5)
ndcg_5_mean = np.mean(ndcg_5)

# %%
# Print evaluation metrics
print("Mean Average Precision (MAP):", map_score)
print("Mean Precision@5:", precision_5_mean)
print("Mean Recall@5:", recall_5_mean)
print("Mean nDCG@5:", ndcg_5_mean)
# Out:
# Mean Average Precision (MAP): 0.5882352941176471
# Mean Precision@5: 0.11764705882352941
# Mean Recall@5: 0.5882352941176471
# Mean nDCG@5: 0.5882352941176471
